# %% [markdown]
# # Grab data

# %%
import pandas as pd
import lib.cleaners as c
import numpy as np

dataset = pd.read_json('dataset/resume_output_Cook-canada.json', lines=True)
dataset.head(10)
print('Dataset (maybe) duplicated:', len(dataset))

dataset = dataset.drop_duplicates(subset=['id'])
print('Dataset non-duplicated:', len(dataset))
# Out:
# Dataset (maybe) duplicated: 9977
# Dataset non-duplicated: 9821

# %% [markdown]
# # Expanding education data

# %% [markdown]
# Expand education data into multiple rows

# %%
edu_df = c.expand_to_multi_rows(dataset, 'schools', 'school')
edu_df = edu_df[['id', 'school']]
edu_df.head(10)
# Out:
#                  id                                             school
# 0  54a3bd53808e6764  {'degree': '', 'school_name': 'Queen Elizabeth...
# 1  54a3bd53808e6764  {'degree': '', 'school_name': 'Kpu', 'start_da...
# 2  f8dc5fa9fc39c387  {'degree': 'High School Diploma in Technical T...
# 3  0e84aa0202047520  {'degree': 'Certificate in French Immersion', ...
# 4  67b00f0985c8948a  {'degree': 'in Mechanics and German Language S...
# 5  89c76f9c1242c552  {'degree': 'Professional cooks lvl 1 in Culina...
# 6  89c76f9c1242c552  {'degree': 'High school  diploma', 'school_nam...
# 7  84ebc2bebda72365  {'degree': 'High School Diploma', 'school_name...
# 8  017658f6f804297c  {'degree': 'apprenticehip in the field of cook...
# 9  b61c261f28ab69be  {'degree': 'High school', 'school_name': 'Sril...

# %% [markdown]
# Make dataframe out of the education dictionary

# %%
degree_df = c.create_new_df_dict_col(edu_df, 'school')

# %% [markdown]
# Delete NaN degrees and replace empty strings to NaN

# %%
degree_df = degree_df.replace('', np.nan)
degree_df = degree_df.dropna(subset=['degree'])
degree_df.head(10)
# Out:
#                                                degree  \
# 2            High School Diploma in Technical Theater
# 3                     Certificate in French Immersion
# 4            in Mechanics and German Language Studies
# 5           Professional cooks lvl 1 in Culinary arts
# 6                                High school  diploma
# 7                                 High School Diploma
# 8   apprenticehip in the field of cooking in culin...
# 9                                         High school
# 10  Master's degree in Mechanical engineering (Tec...
# 11                          High school or equivalent
#
#                                           school_name      start_date  \
# 2                          BISHOP CARROLL HIGH SCHOOL  September 2016
# 3                    Ecole Connaught Community School    January 2011
# 4                          Hassi Messaoud High School             NaN
# 5                                             Collage        May 2013
# 6                            Fleetwood park secondary  September 2007
# 7                                Hamilton High School        May 1975
# 8                         vancouver island university       June 1989
# 9                                            Srilanka             NaN
# 10  Vysoká škola báňská - Technická univerzita Ost...  September 2013
# 11                                                NaN             NaN
#
#       end_date
# 2      Present
# 3          NaN
# 4          NaN
# 5   April 2014
# 6    June 2012
# 7     May 1979
# 8     May 1991
# 9          NaN
# 10   June 2018
# 11         NaN

# %% [markdown]
# Simplifying degree data (it modifies the given DataFrame)

# %%
c.simplify_education_information_(degree_df, 'start_date', 'end_date')
simplified_degree_df = degree_df[['degree', 'degree_year_time']]
simplified_degree_df.head(10)
# Out:
#                                                degree  degree_year_time
# 2            High School Diploma in Technical Theater               NaN
# 3                     Certificate in French Immersion               NaN
# 4            in Mechanics and German Language Studies               NaN
# 5           Professional cooks lvl 1 in Culinary arts          0.917199
# 6                                High school  diploma          4.750269
# 7                                 High School Diploma          4.000082
# 8   apprenticehip in the field of cooking in culin...          1.913797
# 9                                         High school               NaN
# 10  Master's degree in Mechanical engineering (Tec...          4.747531
# 11                          High school or equivalent               NaN

# %% [markdown]
# Combine into original DF with ID

# %%
edu_df = edu_df[['id']]
expanded_resume_degree = pd.merge(edu_df, simplified_degree_df, left_index=True, right_index=True)
expanded_resume_degree.head(10)
# Out:
#                   id                                             degree  \
# 2   f8dc5fa9fc39c387           High School Diploma in Technical Theater
# 3   0e84aa0202047520                    Certificate in French Immersion
# 4   67b00f0985c8948a           in Mechanics and German Language Studies
# 5   89c76f9c1242c552          Professional cooks lvl 1 in Culinary arts
# 6   89c76f9c1242c552                               High school  diploma
# 7   84ebc2bebda72365                                High School Diploma
# 8   017658f6f804297c  apprenticehip in the field of cooking in culin...
# 9   b61c261f28ab69be                                        High school
# 10  708b408f8988a22e  Master's degree in Mechanical engineering (Tec...
# 11  6f73b4d1ab8579ad                          High school or equivalent
#
#     degree_year_time
# 2                NaN
# 3                NaN
# 4                NaN
# 5           0.917199
# 6           4.750269
# 7           4.000082
# 8           1.913797
# 9                NaN
# 10          4.747531
# 11               NaN

# %% [markdown]
# # Expanding skills data

# %% [markdown]
# Expand skills data to multiple rows

# %%
skills_df = c.expand_to_multi_rows(dataset, 'skills', 'skill_dict')
skills_df.head(10)
# Out:
#                                           additional                id  \
# 0  [Skills, -Good writing and reading abilities.,...  0e84aa0202047520
# 1  [Skills, -Good writing and reading abilities.,...  0e84aa0202047520
# 2  [Skills, -Good writing and reading abilities.,...  0e84aa0202047520
# 3  [Currently looking for full time job (prefere ...  708b408f8988a22e
# 4  [Currently looking for full time job (prefere ...  708b408f8988a22e
# 5  [Currently looking for full time job (prefere ...  708b408f8988a22e
# 6  [Currently looking for full time job (prefere ...  708b408f8988a22e
# 7  [Skills, ● High energy attitude, ● Sales exper...  c7675c0b793f34a0
# 8  [Skills, ● High energy attitude, ● Sales exper...  c7675c0b793f34a0
# 9  [Skills, ● High energy attitude, ● Sales exper...  c7675c0b793f34a0
#
#                                                 jobs  \
# 0  [{'title': 'Line Cook and Prep Cook', 'company...
# 1  [{'title': 'Line Cook and Prep Cook', 'company...
# 2  [{'title': 'Line Cook and Prep Cook', 'company...
# 3  [{'title': 'Dishwasher/Line Cook', 'company': ...
# 4  [{'title': 'Dishwasher/Line Cook', 'company': ...
# 5  [{'title': 'Dishwasher/Line Cook', 'company': ...
# 6  [{'title': 'Dishwasher/Line Cook', 'company': ...
# 7  [{'title': 'Manager', 'company': 'Pizza Hut', ...
# 8  [{'title': 'Manager', 'company': 'Pizza Hut', ...
# 9  [{'title': 'Manager', 'company': 'Pizza Hut', ...
#
#                                              schools  \
# 0  [{'degree': 'Certificate in French Immersion',...
# 1  [{'degree': 'Certificate in French Immersion',...
# 2  [{'degree': 'Certificate in French Immersion',...
# 3  [{'degree': 'Master's degree in Mechanical eng...
# 4  [{'degree': 'Master's degree in Mechanical eng...
# 5  [{'degree': 'Master's degree in Mechanical eng...
# 6  [{'degree': 'Master's degree in Mechanical eng...
# 7  [{'degree': 'Certificate', 'school_name': 'Geo...
# 8  [{'degree': 'Certificate', 'school_name': 'Geo...
# 9  [{'degree': 'Certificate', 'school_name': 'Geo...
#
#                                               skills  \
# 0  [{'skill': 'COOKING', 'experience': '4 years'}...
# 1  [{'skill': 'COOKING', 'experience': '4 years'}...
# 2  [{'skill': 'COOKING', 'experience': '4 years'}...
# 3  [{'skill': 'Microsoft Office', 'experience': '...
# 4  [{'skill': 'Microsoft Office', 'experience': '...
# 5  [{'skill': 'Microsoft Office', 'experience': '...
# 6  [{'skill': 'Microsoft Office', 'experience': '...
# 7  [{'skill': 'CUSTOMER RELATIONS', 'experience':...
# 8  [{'skill': 'CUSTOMER RELATIONS', 'experience':...
# 9  [{'skill': 'CUSTOMER RELATIONS', 'experience':...
#
#                                              summary  \
# 0  [Well organized, focused individual who strive...
# 1  [Well organized, focused individual who strive...
# 2  [Well organized, focused individual who strive...
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [Looking for part-time position. Goal focused ...
# 8  [Looking for part-time position. Goal focused ...
# 9  [Looking for part-time position. Goal focused ...
#
#                                           skill_dict
# 0      {'skill': 'COOKING', 'experience': '4 years'}
# 1  {'skill': 'HAND TOOLS', 'experience': 'Less th...
# 2  {'skill': 'WHMIS', 'experience': 'Less than 1 ...
# 3  {'skill': 'Microsoft Office', 'experience': '9...
# 4     {'skill': 'Inventor', 'experience': '8 years'}
# 5          {'skill': 'Cad', 'experience': '8 years'}
# 6  {'skill': 'Creo Parametric', 'experience': '2 ...
# 7  {'skill': 'CUSTOMER RELATIONS', 'experience': ...
# 8  {'skill': 'CUSTOMER SUPPORT', 'experience': 'L...
# 9  {'skill': 'PROBLEM SOLVING', 'experience': 'Le...

# %% [markdown]
# Create a DF using the dictionary of skills

# %%
expanded_skill_df = c.create_new_df_dict_col(skills_df, 'skill_dict')
expanded_skill_df.head(10)
# Out:
#                 skill        experience
# 0             COOKING           4 years
# 1          HAND TOOLS  Less than 1 year
# 2               WHMIS  Less than 1 year
# 3    Microsoft Office           9 years
# 4            Inventor           8 years
# 5                 Cad           8 years
# 6     Creo Parametric           2 years
# 7  CUSTOMER RELATIONS  Less than 1 year
# 8    CUSTOMER SUPPORT  Less than 1 year
# 9     PROBLEM SOLVING  Less than 1 year

# %% [markdown]
# Simplify skills information

# %%
c.simplify_skills_information_(expanded_skill_df, 'experience')
expanded_skill_df.head(10)
# Out:
#                 skill experience
# 0             COOKING          4
# 1          HAND TOOLS          1
# 2               WHMIS          1
# 3    Microsoft Office          9
# 4            Inventor          8
# 5                 Cad          8
# 6     Creo Parametric          2
# 7  CUSTOMER RELATIONS          1
# 8    CUSTOMER SUPPORT          1
# 9     PROBLEM SOLVING          1

# %% [markdown]
# Combine into original DF with ID

# %%
skills_df = skills_df[['id']]
expanded_resume_skills = pd.merge(skills_df, expanded_skill_df, left_index=True, right_index=True)
expanded_resume_skills.head(10)
# Out:
#                  id               skill experience
# 0  0e84aa0202047520             COOKING          4
# 1  0e84aa0202047520          HAND TOOLS          1
# 2  0e84aa0202047520               WHMIS          1
# 3  708b408f8988a22e    Microsoft Office          9
# 4  708b408f8988a22e            Inventor          8
# 5  708b408f8988a22e                 Cad          8
# 6  708b408f8988a22e     Creo Parametric          2
# 7  c7675c0b793f34a0  CUSTOMER RELATIONS          1
# 8  c7675c0b793f34a0    CUSTOMER SUPPORT          1
# 9  c7675c0b793f34a0     PROBLEM SOLVING          1

# %% [markdown]
# # Clean summary data

# %%
pd.set_option('display.max_colwidth', 200)
cleaned_summary = c.clean_array_of_sentences(dataset, 'summary')
cleaned_summary.head(10)
# Out:
# 0                                                                                                                               [obtain, parttime, job, atmosphere, use, improve, customer, service, skills]
# 1                                                                                                                                                                                                         []
# 2    [well, organized, focused, individual, strives, enhance, workplace, enjoy, contributing, participating, kind, healthy, work, environment, prepared, offer, support, needed, adaptable, alert, attent...
# 3                                                                                                                                                                                        [driving, position]
# 4                                                                                                                                                                                                         []
# 5                                                                                                                                                                                                         []
# 6                                                                                                                                                                                                         []
# 7                                                                                                                                                                                                         []
# 8                                                                                                                                                                                                         []
# 9                                                                                [obtain, full, time, position, monday, friday, many, years, experience, looking, career, apply, skills, learn, new, things]
# Name: summary, dtype: object

# %% [markdown]
# # Clean additional data

# %%
pd.set_option('display.max_colwidth', 200)
# just 
cleaned_additional = c.clean_array_of_sentences(dataset, 'additional', clean_punctuation=False)
cleaned_additional.head(50,)
# Out:
# 0     [skills, &, abilities, :, , young, ,, energetic, hard, working, ., , responsible, punctual, ., , able, work, independently, team, player, ., , adaptable, willing, learn, new, concepts, ., , excell...
# 1     [skills, , reliability, , leadership, management, , research, information, gathering, skills, , listening, skills, , creativity, innovation, , ability, manage, organize, information, , sense, resp...
# 2     [skills, good, writing, reading, abilities, ., able, speak, write, french, english, ., familiar, electronics, computer, equipment, ., proficient, computer, internet, programs, ., able, focus, well...
# 3     [, experienced, handson, worker, ;, construction, experience, ,, driving, , responsible, worker, , polite, , accurate, ;, pay, attention, detail, , good, physical, condition, eager, work, , good, ...
# 4                                                                                                                                          [currently, looking, part, time, work, evenings, 34, nights, week]
# 8     [currently, looking, full, time, job, (, prefere, morning, shift, ), ., intrested, ,, please, contact, via, email, ermis.j, @, seznam.cz.my, visa, wh, expirate, august, 2019., thank, looking, forw...
# 9     [great, experience, working, team, environment, well, alone, great, people, customer, service, skills, willingness, learn, new, things, hard, working, quick, learner, lots, experience, working, fa...
# 10                [skills, , high, energy, attitude, , sales, expertise, , team, leadership, , customer, relations, , complex, problem, solving, , time, management, , active, learning, , customer, support]
# 11    [skills, summary, highly, talented, cook, extensive, experience, preparing, ,, seasoning, cooking, wide, variety, meats, ,, fish, fowl, ,, vegetables, ,, soups, stocks, ,, breakfast, dishes, ,, pa...
